# %%
import bs4 as bs
import pickle
import os
import requests
import datetime as dt
import pandas as pd
import os
import pandas_datareader.data as web
import matplotlib.pyplot as plt
from matplotlib import style
import seaborn as sb

# %%
import yfinance as yf
from pandas_datareader import data as pdr
yf.pdr_override()

# %% [markdown]
# Extracting S&P500 Companies Data

# %%
resp = requests.get('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')
soup = bs.BeautifulSoup(resp.text,"lxml")

# %%
table = soup.find('table',{'class':'wikitable sortable'})

# %%
tickers = []
for row in table.findAll('tr')[1:]:
    ticker = row.findAll('td')[0].text
    tickers.append(ticker[:-1])

# %%
with open("s&p500tickers.pickle","wb") as f:
    pickle.dump(tickers,f)

print(tickers)
# Out:
# ['MMM', 'AOS', 'ABT', 'ABBV', 'ACN', 'ATVI', 'ADM', 'ADBE', 'ADP', 'AAP', 'AES', 'AFL', 'A', 'APD', 'AKAM', 'ALK', 'ALB', 'ARE', 'ALGN', 'ALLE', 'LNT', 'ALL', 'GOOGL', 'GOOG', 'MO', 'AMZN', 'AMCR', 'AMD', 'AEE', 'AAL', 'AEP', 'AXP', 'AIG', 'AMT', 'AWK', 'AMP', 'ABC', 'AME', 'AMGN', 'APH', 'ADI', 'ANSS', 'AON', 'APA', 'AAPL', 'AMAT', 'APTV', 'ACGL', 'ANET', 'AJG', 'AIZ', 'T', 'ATO', 'ADSK', 'AZO', 'AVB', 'AVY', 'AXON', 'BKR', 'BALL', 'BAC', 'BBWI', 'BAX', 'BDX', 'WRB', 'BRK.B', 'BBY', 'BIO', 'TECH', 'BIIB', 'BLK', 'BK', 'BA', 'BKNG', 'BWA', 'BXP', 'BSX', 'BMY', 'AVGO', 'BR', 'BRO', 'BF.B', 'BG', 'CHRW', 'CDNS', 'CZR', 'CPT', 'CPB', 'COF', 'CAH', 'KMX', 'CCL', 'CARR', 'CTLT', 'CAT', 'CBOE', 'CBRE', 'CDW', 'CE', 'CNC', 'CNP', 'CDAY', 'CF', 'CRL', 'SCHW', 'CHTR', 'CVX', 'CMG', 'CB', 'CHD', 'CI', 'CINF', 'CTAS', 'CSCO', 'C', 'CFG', 'CLX', 'CME', 'CMS', 'KO', 'CTSH', 'CL', 'CMCSA', 'CMA', 'CAG', 'COP', 'ED', 'STZ', 'CEG', 'COO', 'CPRT', 'GLW', 'CTVA', 'CSGP', 'COST', 'CTRA', 'CCI', 'CSX', 
# ...

# %%
with open("s&p500tickers.pickle",'rb') as f:
    tickers = pickle.load(f)

# %%
if not os.path.exists('stock_dfs'):
    os.makedirs("stock_dfs")

# %%
start = dt.datetime(2012, 1, 1)
end = dt.datetime(2017, 12, 31)

for ticker in tickers:
    df = pdr.get_data_yahoo(ticker,start,end)
    df.to_csv("stock_dfs/{}.csv".format(ticker))
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ...

# %%
df_new = pd.DataFrame()

# %%
for i,ticker in enumerate(tickers):
    df = pd.read_csv("stock_dfs/{}.csv".format(ticker))
    df.set_index('Date',inplace=True)
    df.rename(columns={"Adj Close":ticker},inplace=True)
    df.drop(['Open','High','Close','Low','Volume'],axis=1,inplace=True)

    if df_new.empty:
        df_new = df
    else:
        df_new = df_new.join(df,how='outer')
    
    if i%50==0:
        print(i)
# Out:
# 0
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500

# %%
df_new.head()
# Out:
#                   MMM       AOS        ABT  ABBV        ACN       ATVI  \
# Date
# 2012-01-03  59.109314  8.707094  21.600246   NaN  42.788334  11.129881
# 2012-01-04  59.597832  8.846336  21.516459   NaN  42.772186  11.047776
# 2012-01-05  59.328793  8.863216  21.466955   NaN  41.955997  11.047776
# 2012-01-06  59.024342  8.806252  21.272734   NaN  41.883274  11.166373
# 2012-01-09  59.378357  8.854777  21.268932   NaN  41.810543  11.129881
#
#                   ADM       ADBE        ADP        AAP  ...        WTW  \
# Date                                                    ...
# 2012-01-03  21.302149  28.570000  36.752552  63.330399  ...  82.254196
# 2012-01-04  21.656082  28.280001  36.712051  64.815117  ...  81.787804
# 2012-01-05  21.560219  28.480000  36.981995  65.227554  ...  83.208176
# 2012-01-06  21.434868  28.719999  37.035976  65.529999  ...  82.508583
# 2012-01-09  21.316898  28.530001  36.894260  65.511673  ...  81.809013
#
# ...

# %%
df_new.to_csv("sp500_joined.csv")

# %% [markdown]
# Correlation

# %%
df = pd.read_csv("sp500_joined.csv",index_col='Date')
df.head()
# Out:
#                   MMM       AOS        ABT  ABBV        ACN       ATVI  \
# Date
# 2012-01-03  59.109314  8.707094  21.600246   NaN  42.788334  11.129881
# 2012-01-04  59.597832  8.846336  21.516459   NaN  42.772186  11.047776
# 2012-01-05  59.328793  8.863216  21.466955   NaN  41.955997  11.047776
# 2012-01-06  59.024342  8.806252  21.272734   NaN  41.883274  11.166373
# 2012-01-09  59.378357  8.854777  21.268932   NaN  41.810543  11.129881
#
#                   ADM       ADBE        ADP        AAP  ...        WTW  \
# Date                                                    ...
# 2012-01-03  21.302149  28.570000  36.752552  63.330399  ...  82.254196
# 2012-01-04  21.656082  28.280001  36.712051  64.815117  ...  81.787804
# 2012-01-05  21.560219  28.480000  36.981995  65.227554  ...  83.208176
# 2012-01-06  21.434868  28.719999  37.035976  65.529999  ...  82.508583
# 2012-01-09  21.316898  28.530001  36.894260  65.511673  ...  81.809013
#
# ...

# %%
df_corr = df.corr()
df_corr.head()
# Out:
#            MMM       AOS       ABT      ABBV       ACN      ATVI       ADM  \
# MMM   1.000000  0.970579  0.920203  0.943384  0.961463  0.936002  0.749642
# AOS   0.970579  1.000000  0.864127  0.885185  0.984193  0.966389  0.657867
# ABT   0.920203  0.864127  1.000000  0.937071  0.864730  0.820492  0.782658
# ABBV  0.943384  0.885185  0.937071  1.000000  0.890006  0.867747  0.579307
# ACN   0.961463  0.984193  0.864730  0.890006  1.000000  0.958611  0.626555
#
#           ADBE       ADP       AAP  ...       WTW       GWW      WYNN  \
# MMM   0.974809  0.986363  0.548013  ...  0.965230  0.106717  0.138555
# AOS   0.973537  0.972437  0.523198  ...  0.950843  0.017614 -0.015743
# ABT   0.886958  0.908375  0.547465  ...  0.910878  0.144096  0.183816
# ABBV  0.926126  0.917250  0.251087  ...  0.923933 -0.355857 -0.042141
# ACN   0.970080  0.966206  0.526004  ...  0.935352  0.021938 -0.043063
#
#            XEL       XYL       YUM      ZBRA       ZBH      ZION       ZTS
# ...

# %%
dataplot = sb.heatmap(df.corr(), cmap=plt.cm.RdYlGn, annot=True)
plt.show()
